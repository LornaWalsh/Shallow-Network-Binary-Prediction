# %% [markdown]
# # Shallow Network Binary Prediction

# %% [markdown]
# ### Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Data handeling and evaluation metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Network
from keras.models import Sequential
from keras.layers import Input, Dense
from keras import callbacks
from tensorflow.keras.layers import InputLayer

from ann_visualizer.visualize import ann_viz;

# %% [markdown]
# ### Read data

# %%
# Raw data
dftrain = pd.read_csv('loantrain.csv')

# Make working copy
train = dftrain.copy()

# %%
# View data for visual inspection
train
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %% [markdown]
# ### Preprosessing

# %%
# Remove Loan_ID
train = train.drop('Loan_ID',axis=1)

# %%
#Count of missing 
train.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# #### Missing Values

# %%
# Imputtation of catagorical data - MODE
def mode_imput(data):
    str_list=['Gender','Married','Dependents','Self_Employed','Credit_History','Loan_Amount_Term']
   
    for column in data.columns:     
         for i in range(len(str_list)):                    
            data[str_list[i]].fillna(data[str_list[i]].mode()[0], inplace=True)
        
    return data

# %%
# Imputtation of catagorical data - MEDIAN
def median_imput(data):
    str_list=['LoanAmount','ApplicantIncome','CoapplicantIncome']
    
    for column in data.columns:  
         for i in range(len(str_list)):            
            data[str_list[i]].fillna(data[str_list[i]].median(), inplace=True)      
                    
    return data

# %%
# Call modal imputation function
train=mode_imput(train)

# %%
# Call median imputation function
train=median_imput(train)

# %%
# Map numerical values to catagorical data
def num_map(data):
    data['Gender'] = data['Gender'].map({'Male': 0, 'Female': 1})
    data['Married'] = data['Married'].map({'No': 0, 'Yes': 1})
    data['Dependents'] = data['Dependents'].map({'0': 0, '1': 1, '2': 2, '3+': 3})
    data['Education'] = data['Education'].map({'Graduate': 1, 'Not Graduate': 0})
    data['Self_Employed'] = data['Self_Employed'].map({'No': 0, 'Yes': 1})
    data['Property_Area'] = data['Property_Area'].map({'Rural': 0, 'Semiurban': 1, 'Urban': 2})
    data['Loan_Status'] = data['Loan_Status'].map({'N': 0, 'Y': 1})
        
    return data

# %%
# Call mapping function
train=num_map(train)

# %% [markdown]
# #### Normalise

# %%
# Function for min-max scaling
def min_max_scaling(data):
    for column in data.columns:
        data[column] = (data[column] - data[column].min()) / (data[column].max() - data[column].min())       
    return data

# %%
# Call min-max function
train = min_max_scaling(train)

# %%
# View processed data
train
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       0.0      0.0    0.000000        1.0            0.0         0.070489
# 1       0.0      1.0    0.333333        1.0            0.0         0.054830
# 2       0.0      1.0    0.000000        1.0            1.0         0.035250
# 3       0.0      1.0    0.000000        0.0            0.0         0.030093
# 4       0.0      0.0    0.000000        1.0            0.0         0.072356
# ..      ...      ...         ...        ...            ...              ...
# 609     1.0      0.0    0.000000        1.0            0.0         0.034014
# 610     0.0      1.0    1.000000        1.0            0.0         0.048930
# 611     0.0      1.0    0.333333        1.0            0.0         0.097984
# 612     0.0      1.0    0.666667        1.0            0.0         0.091936
# 613     1.0      0.0    0.000000        1.0            1.0         0.054830
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0             0.000000    0.172214          0.743590             1.0
# 1             0.036192    0.172214          0.743590             1.0
# 2             0.000000    0.082489          0.743590             1.0
# 3             0.056592    0.160637          0.743590             1.0
# 4             0.000000    0.191027          0.743590             1.0
# ..                 ...         ...               ...             ...
# 609           0.000000    0.089725          0.743590             1.0
# 610           0.000000    0.044863          0.358974             1.0
# 611           0.005760    0.353111          0.743590             1.0
# 612           0.000000    0.257598          0.743590             1.0
# 613           0.000000    0.179450          0.743590             0.0
#
#      Property_Area  Loan_Status
# 0              1.0          1.0
# 1              0.0          0.0
# 2              1.0          1.0
# 3              1.0          1.0
# 4              1.0          1.0
# ..             ...          ...
# 609            0.0          1.0
# 610            0.0          1.0
# 611            1.0          1.0
# 612            1.0          1.0
# 613            0.5          0.0
#
# [614 rows x 12 columns]

# %% [markdown]
# #### Split data

# %%
#Train data
# Remove target vairiable and store in seperate array
X_train = train.drop('Loan_Status',axis=1)
Y_train = train.Loan_Status

# Testing Data - 10%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.1, stratify=train['Loan_Status'], random_state = 42)

# Split into training (80%) and validation (20%)
x_train, x_val, y_train, y_val = train_test_split (X_train, Y_train, test_size=0.2, stratify = Y_train, random_state = 42)
# Stratify ensure perameter proportionality in the split, based on Y_train in this case
# Random_state value provides a reproducable shuffle before the data is split

# %%
# Visual comfirmation of proportional split

# x_train as a percentage of train
plt.bar('Train',(x_train.count()/train.count()),align='center', width=-0.5)
# x_val as a percentage of train
plt.bar('Validation',(x_val.count()/train.count()), align='center', width=-0.5)

# Titles 
plt.xlabel('Data')
plt.ylabel('Proportion')
plt.title('Visual Confirmation of Proportional Split')

# Plot
plt.show()

# %% [markdown]
# ### Model

# %% [markdown]
# #### Initial architecture
#
# . Feedforward (Sequencial)
#
# . Fully connected (Dense class)
#
# . Single hidden layer
#
# . 6 neurons in hidden layer (2/3 of input dimention)
#
# . Relu activation function in hidden layer
#
# . Sigmoid activation function in output layer

# %%
# build model with 1 hidden layer and sequencial single connecions
model = Sequential([
    Dense(units=6, activation='relu', input_shape=(x_train.shape[1], )),
    Dense(units=1, activation='sigmoid')
])

# %%
# Compile with optimiser, loss function, and accuracy metric
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
x=x_train
x.count()
# Out:
# Gender               491
# Married              491
# Dependents           491
# Education            491
# Self_Employed        491
# ApplicantIncome      491
# CoapplicantIncome    491
# LoanAmount           491
# Loan_Amount_Term     491
# Credit_History       491
# Property_Area        491
# dtype: int64

# %%
y=y_train
y.count()
# Out:
# 491

# %%
#Train network

# Avoid overfitting
earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 5, 
                                        restore_best_weights = True)
# Train
history = model.fit(x=x_train, y=y_train, epochs = 50, validation_data =(x_val, y_val), 
                    callbacks =[earlystopping])
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 13ms/step - loss: 0.8165 - accuracy: 0.3401 - val_loss: 0.7740 - val_accuracy: 0.3659
# Epoch 2/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.7548 - accuracy: 0.3849 - val_loss: 0.7173 - val_accuracy: 0.4634
# Epoch 3/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.7073 - accuracy: 0.5153 - val_loss: 0.6750 - val_accuracy: 0.5691
# Epoch 4/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6722 - accuracy: 0.6273 - val_loss: 0.6422 - val_accuracy: 0.7317
# Epoch 5/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6453 - accuracy: 0.6640 - val_loss: 0.6164 - val_accuracy: 0.7317
# Epoch 6/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6252 - accuracy: 0.6925 - val_loss: 0.5979 - val_accuracy: 0.7398
# Epoch 7/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6113 - accuracy: 0.7026 - val_loss: 0.5822 - val_accuracy: 0.7398
# Epoch 8/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6000 - accuracy: 0.7169 - val_loss: 0.5705 - val_accuracy: 0.7561
# Epoch 9/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5922 - accuracy: 0.7128 - val_loss: 0.5607 - val_accuracy: 0.7642
# Epoch 10/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5855 - accuracy: 0.7149 - val_loss: 0.5541 - val_accuracy: 0.7642
# Epoch 11/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5817 - accuracy: 0.7128 - val_loss: 0.5477 - val_accuracy: 0.7561
# Epoch 12/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5780 - accuracy: 0.7149 - val_loss: 0.5425 - val_accuracy: 0.7642
# Epoch 13/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5751 - accuracy: 0.7128 - val_loss: 0.5384 - val_accuracy: 0.7642
# Epoch 14/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5731 - accuracy: 0.7108 - val_loss: 0.5347 - val_accuracy: 0.7642
# Epoch 15/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5710 - accuracy: 0.7128 - val_loss: 0.5310 - val_accuracy: 0.7724
# Epoch 16/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5689 - accuracy: 0.7149 - val_loss: 0.5276 - val_accuracy: 0.7724
# Epoch 17/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5669 - accuracy: 0.7149 - val_loss: 0.5240 - val_accuracy: 0.7724
# Epoch 18/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5651 - accuracy: 0.7230 - val_loss: 0.5208 - val_accuracy: 0.7805
# Epoch 19/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5632 - accuracy: 0.7271 - val_loss: 0.5177 - val_accuracy: 0.7805
# Epoch 20/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5614 - accuracy: 0.7312 - val_loss: 0.5152 - val_accuracy: 0.7805
# Epoch 21/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5598 - accuracy: 0.7332 - val_loss: 0.5127 - val_accuracy: 0.7805
# Epoch 22/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5581 - accuracy: 0.7312 - val_loss: 0.5101 - val_accuracy: 0.7967
# Epoch 23/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5565 - accuracy: 0.7352 - val_loss: 0.5077 - val_accuracy: 0.8049
# Epoch 24/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5549 - accuracy: 0.7352 - val_loss: 0.5049 - val_accuracy: 0.8049
# Epoch 25/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5532 - accuracy: 0.7373 - val_loss: 0.5026 - val_accuracy: 0.8130
# Epoch 26/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5516 - accuracy: 0.7434 - val_loss: 0.5003 - val_accuracy: 0.8211
# Epoch 27/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5501 - accuracy: 0.7475 - val_loss: 0.4975 - val_accuracy: 0.8211
# Epoch 28/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5487 - accuracy: 0.7536 - val_loss: 0.4953 - val_accuracy: 0.8211
# Epoch 29/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5473 - accuracy: 0.7576 - val_loss: 0.4928 - val_accuracy: 0.8211
# Epoch 30/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5457 - accuracy: 0.7637 - val_loss: 0.4909 - val_accuracy: 0.8293
# Epoch 31/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5444 - accuracy: 0.7678 - val_loss: 0.4889 - val_accuracy: 0.8374
# Epoch 32/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5429 - accuracy: 0.7699 - val_loss: 0.4867 - val_accuracy: 0.8455
# Epoch 33/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5417 - accuracy: 0.7739 - val_loss: 0.4849 - val_accuracy: 0.8537
# Epoch 34/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5401 - accuracy: 0.7780 - val_loss: 0.4831 - val_accuracy: 0.8537
# Epoch 35/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5388 - accuracy: 0.7780 - val_loss: 0.4815 - val_accuracy: 0.8537
# Epoch 36/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5380 - accuracy: 0.7800 - val_loss: 0.4786 - val_accuracy: 0.8537
# Epoch 37/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5361 - accuracy: 0.7841 - val_loss: 0.4766 - val_accuracy: 0.8537
# Epoch 38/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5348 - accuracy: 0.7862 - val_loss: 0.4753 - val_accuracy: 0.8537
# Epoch 39/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5334 - accuracy: 0.7923 - val_loss: 0.4737 - val_accuracy: 0.8537
# Epoch 40/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5322 - accuracy: 0.7943 - val_loss: 0.4715 - val_accuracy: 0.8537
# Epoch 41/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5310 - accuracy: 0.7943 - val_loss: 0.4693 - val_accuracy: 0.8537
# Epoch 42/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5299 - accuracy: 0.7943 - val_loss: 0.4672 - val_accuracy: 0.8537
# Epoch 43/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5289 - accuracy: 0.7984 - val_loss: 0.4659 - val_accuracy: 0.8537
# Epoch 44/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5277 - accuracy: 0.7984 - val_loss: 0.4639 - val_accuracy: 0.8537
# Epoch 45/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5265 - accuracy: 0.7984 - val_loss: 0.4629 - val_accuracy: 0.8537
# Epoch 46/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5257 - accuracy: 0.7984 - val_loss: 0.4617 - val_accuracy: 0.8537
# Epoch 47/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5244 - accuracy: 0.7984 - val_loss: 0.4598 - val_accuracy: 0.8537
# Epoch 48/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5238 - accuracy: 0.7984 - val_loss: 0.4574 - val_accuracy: 0.8537
# Epoch 49/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5224 - accuracy: 0.7984 - val_loss: 0.4563 - val_accuracy: 0.8537
# Epoch 50/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5216 - accuracy: 0.7984 - val_loss: 0.4554 - val_accuracy: 0.8537

# %%
# Accuracy of predictions from validation data
prediction = (model.predict(x_val) > 0.5).astype("int32")
print("Accuracy_Score : {}".format(accuracy_score(prediction, y_val) * 100))
# Out:
# Accuracy_Score : 85.36585365853658

# %%
# Plot Loss Function
# Series
train_loss_series = history.history['loss']
val_loss_series = history.history['val_loss']

# Scale x-axis
epochs = range(1, len(train_loss_series) + 1) 

# plot
plt.plot(epochs, train_loss_series, 'go', label='Train')
plt.plot(epochs, val_loss_series, 'purple', label='Validation')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot Accuracy
# Series
train_acc_series = history.history['accuracy']
val_acc_series = history.history['val_accuracy']

# Scale x-axsis
epochs = range(1, len(train_acc_series) + 1)

# plot
plt.plot(epochs, train_acc_series, 'go', label='Train')
plt.plot(epochs, val_acc_series, 'purple', label='Validation')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Run Trained Network

# see how these are numbers between 0 and 1? 
model.predict(x_test) # prob of successes (survival)
np.round(model.predict(x_test),0) # 1 and 0 (survival or not)
y_test # 1 and 0 (survival or not)

# so we need to round to a whole number (0 or 1),
# or the confusion matrix won't work!
preds = np.round(model.predict(x_test),0)

# confusion matrix
print(confusion_matrix(y_test, preds)) # order matters! (actual, predicted)
print(classification_report(y_test, preds))
# Out:
# [[ 9 10]
#  [ 1 42]]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.47      0.62        19
#          1.0       0.81      0.98      0.88        43
#
#     accuracy                           0.82        62
#    macro avg       0.85      0.73      0.75        62
# weighted avg       0.84      0.82      0.80        62
